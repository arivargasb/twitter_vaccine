# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import json

# %%
tweets = pd.read_csv('vaccine_us_0720to0121.csv')
tweets.head()
# Out:
#                     id      conversation_id               created_at        date      time  timezone              user_id         username                     name place                                              tweet language mentions                                           urls photos  replies_count  retweets_count  likes_count                hashtags cashtags                                               link  retweet quote_url  video thumbnail  near                                          geo  source  user_rt_id  user_rt  retweet_id                                           reply_to  retweet_date  translate  trans_src  trans_dest
# ...

# %%
# check size of the dataframe
tweets.shape
# Out:
# (294354, 36)

# %%
# check for NaN values
tweets.isna().sum()
# Out:
# id                      0
# conversation_id         0
# created_at              0
# date                    0
# time                    0
# timezone                0
# user_id                 0
# username                3
# name                   14
# place              292451
# tweet                   0
# language                0
# mentions                0
# urls                    0
# photos                  0
# replies_count           0
# retweets_count          0
# likes_count             0
# hashtags                0
# cashtags                0
# link                    0
# retweet                 0
# quote_url          254426
# video                   0
# thumbnail          269591
# near               294354
# geo                     0
# source             294354
# user_rt_id         294354
# user_rt            294354
# retweet_id         294354
# reply_to                0
# retweet_date       294354
# translate          294354
# trans_src          294354
# ...

# %%
# check for strange values
tweets['date'].unique()
# Out:
# array(['2021-01-03', '2021-01-02', '2021-01-01', '2020-12-31',
#        '2020-12-30', '2020-12-29', '2020-12-28', '2020-12-27',
#        '2020-12-26', '2020-12-25', '2020-12-24', '2020-12-23',
#        '2020-12-22', '2020-12-21', '2020-12-20', '2020-12-19',
#        '2020-12-18', '2020-12-17', '2020-12-16', '2020-12-15',
#        '2020-12-14', '2020-12-13', '2020-12-12', '2020-12-11',
#        '2020-12-10', '2020-12-09', '2020-12-08', '2020-12-07',
#        '2020-12-06', '2020-12-05', '2020-12-04', '2020-12-03',
#        '2020-12-02', '2020-12-01', '2020-11-30', '2020-11-29',
#        '2020-11-28', '2020-11-27', '2020-11-26', '2020-11-25',
#        '2020-11-24', '2020-11-23', '2020-11-22', '2020-11-21',
#        '2020-11-20', '2020-11-19', '2020-11-18', '2020-11-17',
#        '2020-11-16', '2020-11-15', '2020-11-14', '2020-11-13',
#        '2020-11-12', '2020-11-11', '2020-11-10', '2020-11-09',
#        '2020-11-08', '2020-11-07', '2020-11-06', '2020-11-05',
# ...

# %%
# create a copy to clean
tweets_clean = tweets.copy()

# check shape
tweets_clean.shape
# Out:
# (294354, 36)

# %%
# drop rows with all NaN values
tweets_clean.dropna(how='all', inplace=True)

# confirm
tweets_clean.shape
# Out:
# (294354, 36)

# %%
# drop duplicate tweets and/or retweets
tweets_clean = tweets_clean.drop_duplicates(subset='tweet')

# confirm
tweets_clean.shape
# Out:
# (293054, 36)

# %%
# take another look at NaN values
tweets_clean.isna().sum()
# Out:
# id                      0
# conversation_id         0
# created_at              0
# date                    0
# time                    0
# timezone                0
# user_id                 0
# username                3
# name                   13
# place              291152
# tweet                   0
# language                0
# mentions                0
# urls                    0
# photos                  0
# replies_count           0
# retweets_count          0
# likes_count             0
# hashtags                0
# cashtags                0
# link                    0
# retweet                 0
# quote_url          253544
# video                   0
# thumbnail          268294
# near               293054
# geo                     0
# source             293054
# user_rt_id         293054
# user_rt            293054
# retweet_id         293054
# reply_to                0
# retweet_date       293054
# translate          293054
# trans_src          293054
# ...

# %%
# drop any tweets missing a value for name (takes care of other NaN values)
tweets_clean.dropna(subset=['name'], inplace=True)
tweets_clean.shape
# Out:
# (293041, 36)

# %%
# drop unwanted columns
tweets_clean.drop(columns=['time', 'timezone', 'place' , 'retweet_id',
                          'language', 'mentions', 'urls', 'photos',
                          'cashtags', 'quote_url', 'video', 'thumbnail',
                          'near', 'geo', 'source', 'user_rt_id',
                          'user_rt', 'retweet_id', 'retweet_date', 'translate',
                          'trans_src', 'trans_dest'], inplace=True)

# %%
tweets_clean
# Out:
#                          id      conversation_id               created_at        date              user_id         username                                              name                                              tweet  replies_count  retweets_count  likes_count                                           hashtags                                               link  retweet                                           reply_to
# 0       1345882628222832641  1345730738814128132  2021-01-03 17:59:58 CST  2021-01-03            117873505  albertosmagus18                                               Ben  @TheMossadIL @JoBiGutenburg02 @guardian Here w...              0               0            0                                                 []  https://twitter.com/albertosmagus18/status/134...    False  [{'screen_name': 'TheMossadIL', 'name': 'The M...
# ...

# %%
# reset index
tweets_clean.reset_index(drop=True, inplace=True)

# confirm
tweets_clean.head()
# Out:
#                     id      conversation_id               created_at        date              user_id         username                     name                                              tweet  replies_count  retweets_count  likes_count                hashtags                                               link  retweet                                           reply_to
# 0  1345882628222832641  1345730738814128132  2021-01-03 17:59:58 CST  2021-01-03            117873505  albertosmagus18                      Ben  @TheMossadIL @JoBiGutenburg02 @guardian Here w...              0               0            0                      []  https://twitter.com/albertosmagus18/status/134...    False  [{'screen_name': 'TheMossadIL', 'name': 'The M...
# ...

# %%
# save to csv
tweets_clean.to_csv('tweets_clean.csv')
